# %%
from faker import Faker

fake = Faker()

print(fake.name())
print(fake.address())
print(fake.email())
print(fake.date_of_birth()) 
print(fake.credit_card_full())
# Out:
# Sara Reyes
# 88199 Roman Terrace
# New Shelleyfurt, MA 41957
# mitchelljustin@example.org
# 2017-02-06
# JCB 15 digit
# Jasmine Saunders
# 180005010951052 01/27
# CVC: 249

# %%
import pandas as pd

# %%
dd = pd.read_csv("Data_Dummie/MOCK_DATA.csv")

# %%
dd["Name"].to_csv("nombres.csv")
